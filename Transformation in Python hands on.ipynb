# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
cruise = pd.read_excel (r'C:\Users\Candy\Downloads\cruise_ship\cruise_ship.xlsx')

# %%
sns.distplot(cruise['YearBlt'])
# Out:
# C:\tools\Anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='YearBlt', ylabel='Density'>

# %%
cruise['YearBltSQ'] = cruise['YearBlt']**2

# %%
cruise.YearBltSQ.hist()
# Out:
# <AxesSubplot:>

# %%
cruise['YearBltCUBE'] = cruise['YearBlt']**3

# %%
cruise.YearBltCUBE.hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# #This is a negative skewed data and cubing gives the best result

# %%
sns.distplot(cruise['Tonnage'])
# Out:
# C:\tools\Anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Tonnage', ylabel='Density'>

# %%
cruise['TonnageSQRT'] = np.sqrt(cruise['Tonnage'])

# %%
cruise.TonnageSQRT.hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# #This is positively distributed but taking the square root makes it normally distributed.

# %%
sns.distplot(cruise['passngrs'])
# Out:
# C:\tools\Anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='passngrs', ylabel='Density'>

# %% [markdown]
# #The data for passengers is a normal distribution

# %%
sns.distplot(cruise['Length'])
# Out:
# C:\tools\Anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Length', ylabel='Density'>

# %%
cruise['LengthSQRT'] = np.sqrt(cruise['Length'])

# %%
cruise.LengthSQRT.hist()
# Out:
# <AxesSubplot:>

# %%
cruise['LengthLOG'] = np.log(cruise['Length'])

# %%
cruise.LengthLOG.hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# #The data for length is negatively skewed and even taking the Log doesn't make it normal but will have to do

# %%
sns.distplot(cruise['Cabins'])
# Out:
# C:\tools\Anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Cabins', ylabel='Density'>

# %% [markdown]
# #The data for Cabins is close to Normal distribution

# %%
sns.distplot(cruise['Crew'])
# Out:
# C:\tools\Anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Crew', ylabel='Density'>

# %% [markdown]
# #the data for crew is normal distributed

# %%
sns.distplot(cruise['PassSpcR'])
# Out:
# C:\tools\Anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='PassSpcR', ylabel='Density'>

# %%
cruise['PassSpcRSQ'] = cruise['PassSpcR']**2

# %%
cruise['PassSpcRSQ'].hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# #The data for PassSpcR is close to normal distribution, it is close to positively skewed but if you square it goes too far so it is best to keep original data.

# %%
sns.distplot(cruise['outcab'])
# Out:
# C:\tools\Anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='outcab', ylabel='Density'>

# %% [markdown]
# #This is close to normal distribution
