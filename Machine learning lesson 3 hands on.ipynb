# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from sklearn.ensemble import RandomForestClassifier

# %% [markdown]
# IMPORT DATA

# %%
Titanic = sns.load_dataset('titanic')

# %%
Titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
Titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
Titanic.dropna(inplace = True)

# %%
Titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 182 entries, 1 to 889
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     182 non-null    int64
#  1   pclass       182 non-null    int64
#  2   sex          182 non-null    object
#  3   age          182 non-null    float64
#  4   sibsp        182 non-null    int64
#  5   parch        182 non-null    int64
#  6   fare         182 non-null    float64
#  7   embarked     182 non-null    object
#  8   class        182 non-null    category
#  9   who          182 non-null    object
#  10  adult_male   182 non-null    bool
#  11  deck         182 non-null    category
#  12  embark_town  182 non-null    object
#  13  alive        182 non-null    object
#  14  alone        182 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 18.2+ KB

# %%
Titanic.drop(['who', 'adult_male'], axis =1, inplace = True)
Titanic.head()
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 1          1       1  female  38.0      1      0  71.2833        C  First
# 3          1       1  female  35.0      1      0  53.1000        S  First
# 6          0       1    male  54.0      0      0  51.8625        S  First
# 10         1       3  female   4.0      1      1  16.7000        S  Third
# 11         1       1  female  58.0      0      0  26.5500        S  First
#
#    deck  embark_town alive  alone
# 1     C    Cherbourg   yes  False
# 3     C  Southampton   yes  False
# 6     E  Southampton    no   True
# 10    G  Southampton   yes  False
# 11    C  Southampton   yes   True

# %%
Titanic.pclass.value_counts()
# Out:
# 1    157
# 2     15
# 3     10
# Name: pclass, dtype: int64

# %%
Titanic['class'].value_counts()
# Out:
# First     157
# Second     15
# Third      10
# Name: class, dtype: int64

# %%
Titanic[Titanic['pclass']== 2]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 21          1       2    male  34.0      0      0  13.0000        S  Second
# 66          1       2  female  29.0      0      0  10.5000        S  Second
# 123         1       2  female  32.5      0      0  13.0000        S  Second
# 148         0       2    male  36.5      0      2  26.0000        S  Second
# 183         1       2    male   1.0      2      1  39.0000        S  Second
# 193         1       2    male   3.0      1      1  26.0000        S  Second
# 292         0       2    male  36.0      0      0  12.8750        C  Second
# 327         1       2  female  36.0      0      0  13.0000        S  Second
# 340         1       2    male   2.0      1      1  26.0000        S  Second
# 345         1       2  female  24.0      0      0  13.0000        S  Second
# 473         1       2  female  23.0      0      0  13.7917        C  Second
# 516         1       2  female  34.0      0      0  10.5000        S  Second
# 618         1       2  female   4.0      2      1  39.0000        S  Second
# 717         1       2  female  27.0      0      0  10.5000        S  Second
# 772         0       2  female  57.0      0      0  10.5000        S  Second
#
#     deck  embark_town alive  alone
# 21     D  Southampton   yes   True
# 66     F  Southampton   yes   True
# 123    E  Southampton   yes   True
# 148    F  Southampton    no  False
# 183    F  Southampton   yes  False
# 193    F  Southampton   yes  False
# 292    D    Cherbourg    no   True
# 327    D  Southampton   yes   True
# 340    F  Southampton   yes  False
# 345    F  Southampton   yes   True
# 473    D    Cherbourg   yes   True
# 516    F  Southampton   yes   True
# 618    F  Southampton   yes  False
# 717    E  Southampton   yes   True
# 772    E  Southampton    no   True

# %%
Titanic.drop('class', axis = 1, inplace = True)
Titanic.head()
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked deck  \
# 1          1       1  female  38.0      1      0  71.2833        C    C
# 3          1       1  female  35.0      1      0  53.1000        S    C
# 6          0       1    male  54.0      0      0  51.8625        S    E
# 10         1       3  female   4.0      1      1  16.7000        S    G
# 11         1       1  female  58.0      0      0  26.5500        S    C
#
#     embark_town alive  alone
# 1     Cherbourg   yes  False
# 3   Southampton   yes  False
# 6   Southampton    no   True
# 10  Southampton   yes  False
# 11  Southampton   yes   True

# %%
Titanic.survived.value_counts()
# Out:
# 1    123
# 0     59
# Name: survived, dtype: int64

# %%
Titanic.alive.value_counts()
# Out:
# yes    123
# no      59
# Name: alive, dtype: int64

# %%
Titanic.drop('alive', axis = 1, inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-19-2b126760ddc4> in <module>
# ----> 1 Titanic.drop('alive', axis = 1, inplace = True)
#       2 Titanic.head()
#
# C:\tools\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4306                 weight  1.0     0.8
#    4307         """
# -> 4308         return super().drop(
#    4309             labels=labels,
#    4310             axis=axis,
#
# C:\tools\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4151         for axis, labels in axes.items():
#    4152             if labels is not None:
# -> 4153                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4154
#    4155         if inplace:
#
# C:\tools\Anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    4186                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4187             else:
# -> 4188                 new_axis = axis.drop(labels, errors=errors)
#    4189             result = self.reindex(**{axis_name: new_axis})
#    4190
#
# C:\tools\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    5589         if mask.any():
#    5590             if errors != "ignore":
# -> 5591                 raise KeyError(f"{labels[mask]} not found in axis")
#    5592             indexer = indexer[~mask]
#    5593         return self.delete(indexer)
#
# KeyError: "['alive'] not found in axis"

# %%
Titanic.head()
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked deck  \
# 1          1       1  female  38.0      1      0  71.2833        C    C
# 3          1       1  female  35.0      1      0  53.1000        S    C
# 6          0       1    male  54.0      0      0  51.8625        S    E
# 10         1       3  female   4.0      1      1  16.7000        S    G
# 11         1       1  female  58.0      0      0  26.5500        S    C
#
#     embark_town  alone
# 1     Cherbourg  False
# 3   Southampton  False
# 6   Southampton   True
# 10  Southampton  False
# 11  Southampton   True

# %%
Titanic.drop('alone', axis = 1, inplace = True)
Titanic.drop('embark_town', axis = 1, inplace = True)
Titanic.head()
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 1          1       1  female  38.0      1      0  71.2833        C    C
# 3          1       1  female  35.0      1      0  53.1000        S    C
# 6          0       1    male  54.0      0      0  51.8625        S    E
# 10         1       3  female   4.0      1      1  16.7000        S    G
# 11         1       1  female  58.0      0      0  26.5500        S    C

# %%
Titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 182 entries, 1 to 889
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   survived  182 non-null    int64
#  1   pclass    182 non-null    int64
#  2   sex       182 non-null    object
#  3   age       182 non-null    float64
#  4   sibsp     182 non-null    int64
#  5   parch     182 non-null    int64
#  6   fare      182 non-null    float64
#  7   embarked  182 non-null    object
#  8   deck      182 non-null    category
# dtypes: category(1), float64(2), int64(4), object(2)
# memory usage: 13.3+ KB

# %%
Titanic.age = Titanic.age.astype(int)
Titanic.fare = Titanic.fare.astype(int)
Titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 182 entries, 1 to 889
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   survived  182 non-null    int64
#  1   pclass    182 non-null    int64
#  2   sex       182 non-null    object
#  3   age       182 non-null    int32
#  4   sibsp     182 non-null    int64
#  5   parch     182 non-null    int64
#  6   fare      182 non-null    int32
#  7   embarked  182 non-null    object
#  8   deck      182 non-null    category
# dtypes: category(1), int32(2), int64(4), object(2)
# memory usage: 11.9+ KB

# %%
Titanic.deck.value_counts()
# Out:
# C    51
# B    43
# D    31
# E    30
# A    12
# F    11
# G     4
# Name: deck, dtype: int64

# %%
def Deck(series):
    if series == 'A':
        return 0
    if series == 'B':
        return 1
    if series == 'C':
        return 2
    if series == 'D':
        return 3
    if series == 'E':
        return 4
    if series == 'F':
        return 5 
    if series == 'G':
        return 6
Titanic['deckR'] = Titanic['deck'].apply(Deck)
Titanic.drop('deck', axis = 1, inplace = True)
Titanic.deckR = Titanic.deckR.astype(int)

# %%
Titanic.head()
# Out:
#     survived  pclass  age  sibsp  parch  fare  deckR  embarkedR  sexR
# 1          1       1   38      1      0    71      2          1     1
# 3          1       1   35      1      0    53      2          0     1
# 6          0       1   54      0      0    51      4          0     0
# 10         1       3    4      1      1    16      6          0     1
# 11         1       1   58      0      0    26      2          0     1

# %%
Titanic.embarked.value_counts()
# Out:
# S    115
# C     65
# Q      2
# Name: embarked, dtype: int64

# %%
Titanic.sex.value_counts()
# Out:
# male      94
# female    88
# Name: sex, dtype: int64

# %%
def Gender(series):
    if series == 'male':
        return 0
    if series == 'female':
        return 1
Titanic['sexR'] = Titanic['sex'].apply(Gender)
Titanic.drop('sex', axis = 1, inplace = True)
Titanic.sexR = Titanic.sexR.asytpe(int)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-36-e98b636832cf> in <module>
#       6 Titanic['sexR'] = Titanic['sex'].apply(Gender)
#       7 Titanic.drop('sex', axis = 1, inplace = True)
# ----> 8 Titanic.sexR = Titanic.sexR.asytpe(int)
#
# C:\tools\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'asytpe'

# %%
Titanic.head()
# Out:
#     survived  pclass  age  sibsp  parch  fare  deckR  embarkedR  sexR
# 1          1       1   38      1      0    71      2          1     1
# 3          1       1   35      1      0    53      2          0     1
# 6          0       1   54      0      0    51      4          0     0
# 10         1       3    4      1      1    16      6          0     1
# 11         1       1   58      0      0    26      2          0     1

# %%
y = Titanic.survived
y.head()
# Out:
# 1     1
# 3     1
# 6     0
# 10    1
# 11    1
# Name: survived, dtype: int64

# %%
x = Titanic.drop('survived', axis = 1)
x.head()
# Out:
#     pclass  age  sibsp  parch  fare  deckR  embarkedR  sexR
# 1        1   38      1      0    71      2          1     1
# 3        1   35      1      0    53      2          0     1
# 6        1   54      0      0    51      4          0     0
# 10       3    4      1      1    16      6          0     1
# 11       1   58      0      0    26      2          0     1

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3, random_state = 76)

# %%
decisionTree = DecisionTreeClassifier(random_state = 76)
decisionTree.fit (x_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=76)

# %%
treePredictions = decisionTree.predict(x_test)
print(confusion_matrix (y_test, treePredictions))
print (classification_report (y_test, treePredictions))
# Out:
# [[14  5]
#  [ 9 27]]
#               precision    recall  f1-score   support
#
#            0       0.61      0.74      0.67        19
#            1       0.84      0.75      0.79        36
#
#     accuracy                           0.75        55
#    macro avg       0.73      0.74      0.73        55
# weighted avg       0.76      0.75      0.75        55

# %%
forest = RandomForestClassifier(n_estimators = 500, random_state = 76)
forest.fit (x_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=500, random_state=76)

# %%
forestPredictions = forest.predict(x_test)
print(confusion_matrix(y_test, forestPredictions))
print(classification_report(y_test, forestPredictions))
# Out:
# [[14  5]
#  [ 6 30]]
#               precision    recall  f1-score   support
#
#            0       0.70      0.74      0.72        19
#            1       0.86      0.83      0.85        36
#
#     accuracy                           0.80        55
#    macro avg       0.78      0.79      0.78        55
# weighted avg       0.80      0.80      0.80        55

# %% [markdown]
# The decision tree model predicts accuracy 76% of the time but the forest model predicts accuracy 80% of the time.  This means that the forest prediction model is the best model to use in this situation.
